# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
from scipy.ndimage import gaussian_filter1d
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import pencil as pc
from IPython.display import display, Math, Latex
# Out:
# Warning: pencilnew has moved to pencil.
#          pencil has moved to pencil_old.
# To change your scripts accordingly:
# import pencilnew as pc -> import pencil as pc
# import pencil as pc -> import pencil_old as pc
# Warning: Could not import visu.rvid_box. Try:
# $ conda install -c plotly plotly-orca psutil requests

# %%
plt.rcParams.update({'font.size': 16})
plt.rcParams['text.usetex'] = True

# %% [markdown]
# ## Variation of Thermodynamic Variables along z

# %% [markdown]
# ### reading xy_aver file and grid

# %%
#reading the xy_aver file
xya=pc.read.aver(plane_list=['xy'])
#reading the grid
grid = pc.read.grid(trim=True)
z = grid.z
# Out:
# ['xy'] ['xyaver.in'] ['xyaverages.dat']
# ['bxmz', 'bymz', 'rhomz', 'TTmz', 'ppmz', 'ssmz']
# var_index -1
# var_index -1
# var_index -1
# var_index -1
# var_index -1
# var_index -1
# reading grid data from processor 27 of 128 ...
# reading grid data from processor 98 of 128 ...
# reading grid data from processor 54 of 128 ...
# reading grid data from processor 39 of 128 ...
# reading grid data from processor 57 of 128 ...
# reading grid data from processor 86 of 128 ...
# reading grid data from processor 19 of 128 ...
# reading grid data from processor 119 of 128 ...
# reading grid data from processor 92 of 128 ...
# reading grid data from processor 71 of 128 ...
# reading grid data from processor 70 of 128 ...
# reading grid data from processor 56 of 128 ...
# reading grid data from processor 103 of 128 ...
# reading grid data from processor 30 of 128 ...
# reading grid data from processor 112 of 128 ...
# reading grid data from processor 40 of 128 ...
# reading grid data from processor 126 of 128 ...
# reading grid data from processor 60 of 128 ...
# reading grid data from processor 89 of 128 ...
# reading grid data from processor 62 of 128 ...
# reading grid data from processor 93 of 128 ...
# reading grid data from processor 87 of 128 ...
# reading grid data from processor 118 of 128 ...
# reading grid data from processor 117 of 128 ...
# reading grid data from processor 91 of 128 ...
# reading grid data from processor 116 of 128 ...
# reading grid data from processor 69 of 128 ...
# reading grid data from processor 5 of 128 ...
# reading grid data from processor 107 of 128 ...
# reading grid data from processor 1 of 128 ...
# reading grid data from processor 76 of 128 ...
# reading grid data from processor 2 of 128 ...
# reading grid data from processor 47 of 128 ...
# reading grid data from processor 108 of 128 ...
# reading grid data from processor 83 of 128 ...
# reading grid data from processor 111 of 128 ...
# reading grid data from processor 33 of 128 ...
# reading grid data from processor 42 of 128 ...
# reading grid data from processor 82 of 128 ...
# reading grid data from processor 36 of 128 ...
# reading grid data from processor 75 of 128 ...
# reading grid data from processor 31 of 128 ...
# reading grid data from processor 64 of 128 ...
# reading grid data from processor 65 of 128 ...
# reading grid data from processor 46 of 128 ...
# reading grid data from processor 95 of 128 ...
# reading grid data from processor 14 of 128 ...
# reading grid data from processor 35 of 128 ...
# reading grid data from processor 34 of 128 ...
# reading grid data from processor 120 of 128 ...
# reading grid data from processor 66 of 128 ...
# reading grid data from processor 58 of 128 ...
# reading grid data from processor 20 of 128 ...
# reading grid data from processor 53 of 128 ...
# reading grid data from processor 101 of 128 ...
# reading grid data from processor 125 of 128 ...
# reading grid data from processor 48 of 128 ...
# reading grid data from processor 102 of 128 ...
# reading grid data from processor 12 of 128 ...
# reading grid data from processor 59 of 128 ...
# reading grid data from processor 74 of 128 ...
# reading grid data from processor 0 of 128 ...
# reading grid data from processor 4 of 128 ...
# reading grid data from processor 81 of 128 ...
# reading grid data from processor 124 of 128 ...
# reading grid data from processor 99 of 128 ...
# reading grid data from processor 114 of 128 ...
# reading grid data from processor 6 of 128 ...
# reading grid data from processor 52 of 128 ...
# reading grid data from processor 96 of 128 ...
# reading grid data from processor 10 of 128 ...
# reading grid data from processor 26 of 128 ...
# reading grid data from processor 9 of 128 ...
# reading grid data from processor 7 of 128 ...
# reading grid data from processor 32 of 128 ...
# reading grid data from processor 80 of 128 ...
# reading grid data from processor 106 of 128 ...
# reading grid data from processor 97 of 128 ...
# reading grid data from processor 8 of 128 ...
# reading grid data from processor 3 of 128 ...
# reading grid data from processor 84 of 128 ...
# reading grid data from processor 23 of 128 ...
# reading grid data from processor 109 of 128 ...
# reading grid data from processor 51 of 128 ...
# reading grid data from processor 55 of 128 ...
# reading grid data from processor 67 of 128 ...
# reading grid data from processor 25 of 128 ...
# reading grid data from processor 49 of 128 ...
# reading grid data from processor 105 of 128 ...
# reading grid data from processor 50 of 128 ...
# reading grid data from processor 123 of 128 ...
# reading grid data from processor 16 of 128 ...
# reading grid data from processor 18 of 128 ...
# reading grid data from processor 104 of 128 ...
# reading grid data from processor 37 of 128 ...
# reading grid data from processor 122 of 128 ...
# reading grid data from processor 73 of 128 ...
# reading grid data from processor 94 of 128 ...
# reading grid data from processor 21 of 128 ...
# reading grid data from processor 41 of 128 ...
# reading grid data from processor 110 of 128 ...
# reading grid data from processor 72 of 128 ...
# reading grid data from processor 45 of 128 ...
# reading grid data from processor 88 of 128 ...
# reading grid data from processor 15 of 128 ...
# reading grid data from processor 127 of 128 ...
# reading grid data from processor 79 of 128 ...
# reading grid data from processor 121 of 128 ...
# reading grid data from processor 68 of 128 ...
# reading grid data from processor 38 of 128 ...
# reading grid data from processor 43 of 128 ...
# reading grid data from processor 17 of 128 ...
# reading grid data from processor 77 of 128 ...
# reading grid data from processor 22 of 128 ...
# reading grid data from processor 63 of 128 ...
# reading grid data from processor 28 of 128 ...
# reading grid data from processor 13 of 128 ...
# reading grid data from processor 11 of 128 ...
# reading grid data from processor 78 of 128 ...
# reading grid data from processor 44 of 128 ...
# reading grid data from processor 115 of 128 ...
# reading grid data from processor 113 of 128 ...
# reading grid data from processor 100 of 128 ...
# reading grid data from processor 24 of 128 ...
# reading grid data from processor 85 of 128 ...
# reading grid data from processor 90 of 128 ...
# reading grid data from processor 61 of 128 ...
# reading grid data from processor 29 of 128 ...

# %% [markdown]
# ### reading density and temperature from xy_aver

# %%
rho = xya.xy.rhomz[-1,:]
#pre = xya.xy.ppmz[-1,:]
temp = xya.xy.TTmz[-1,:]

# %% [markdown]
# ### calculating pressure

# %%
#reading the var file
var = pc.read.var(magic=["pp"], trimall=True)

# %%
#calculating pressure profile by averaging the var file in xy plane
pressure = np.average(var.pp, axis=(-1,-2))

# %% [markdown]
# ### plotting

# %%
l=-5*np.pi/6
u=np.pi/6

fig, axs = plt.subplots(3,1, figsize=(12,8), sharex=True)

axs[0].plot(grid.z, rho, color='k')
axs[1].plot(grid.z, pressure, color='k')
#axs[1].plot(grid.z, pre, color='k')
axs[2].plot(grid.z, temp, color='k')
#axs[2].plot(grid.z, xya.xy.TTmz[-1], color='k')

axs[0].set_yscale("log")
axs[1].set_yscale("log")
axs[2].set_yscale("log")

axs[0].set_xlim(l, u)
axs[1].set_xlim(l, u)
axs[2].set_xlim(l, u)

axs[0].set_ylabel(r"$\rho(z)$")
axs[1].set_ylabel(r"$P(z)$")
axs[2].set_ylabel(r"$T(z)$")


plt.xlabel("grid (z)")
plt.tight_layout()
#plt.savefig("variation.jpg")

# %% [markdown]
# ## determining the temp of the lower layer

# %% [markdown]
# ### reading timeseries data

# %%
ts = pc.read.ts()
# Out:
# Read 1586 lines.

# %%
def g(t, a):
    return a

i_l = np.argmin(abs(z+2.5))
j_l = np.argmin(abs(z+1.5))

z_l = z[i_l:j_l]
T_l = temp[i_l:j_l]

popt_l, pcov_l = curve_fit(g, z_l, T_l)

z_fit_l = ts.t[i_l:j_l]
T_fit_l = g(z_fit_l, popt_l[0])
T_ave_l = round(np.average(T_fit_l),3)
display(Latex(fr'$T_d$ = {T_ave_l}'))
# Out:
# $T_d$ = 1.5

# %%
i_u = np.argmin(abs(z-0.01))
j_u = np.argmin(abs(z-0.5))

z_u = z[i_u:j_u]
T_u = temp[i_u:j_u]

popt_u, pcov_u = curve_fit(g, z_u, T_u)

z_fit_u = ts.t[i_u:j_u]
T_fit_u = g(z_fit_u, popt_u[0])
T_ave_u = round(np.average(T_fit_u),3)
display(Latex(fr'$T_u$ = {T_ave_u}'))
# Out:
# $T_u$ = 8.159

# %% [markdown]
# ## Calculating other parameters

# %%
param = pc.read.param()
cp = param.cp
display(Latex(fr'$c_p$ = {cp}'))
gamma = np.round(param.gamma, 3)
display(Latex(fr'$\gamma$ = {gamma}'))
R = np.round(cp*(1-(1/gamma)), 4)
display(Latex(fr'$R$ = {R}'))
# Out:
# $c_p$ = 1.0
# $\gamma$ = 1.667
# $R$ = 0.4001

# %%
cs_d = np.round(np.sqrt(gamma*R*T_ave_l), 3)
display(Latex(fr'$c_{{sd}}$ = {cs_d}'))
cs_u = np.round(np.sqrt(gamma*R*T_ave_u), 3)
display(Latex(fr'$c_{{su}}$ = {cs_u}'))
# Out:
# $c_{sd}$ = 1.0
# $c_{su}$ = 2.333

# %%
g = 1
L0 = np.round(cs_d**2/g, 3)
display(Latex(fr'$L_0$ = {L0}'))
omega0 = np.round(g/cs_d, 3)
display(Latex(fr'$\omega_0$ = {omega0}'))
# Out:
# $L_0$ = 1.0
# $\omega_0$ = 1.0

# %%
#for st_li2ne fi2tti2ng
def g(t, a, b):
    return a*t+b

i2 = np.argmin(abs(ts.t-200))
j2 = np.argmin(abs(ts.t-650))

t_lin = ts.t[i2:j2]
u_lin = ts.urms[i2:j2]

popt, pcov = curve_fit(g, t_lin, u_lin)

t_fit = ts.t[i2:j2]
u_fit = g(t_fit, popt[0], popt[1])
u_ave = round(np.average(u_fit),4)
display(Latex(fr'$u_{{rms}}$ = {u_ave}'))
#np.shape(i2)
#u_fit
# Out:
# $u_{rms}$ = 0.0247

# %% [markdown]
# ### plotting

# %%
fig = plt.figure(figsize=(16,4))
plt.plot(ts.t, ts.urms, alpha=0.6)
plt.plot(t_fit, u_fit, '--r')
plt.yscale('log')
plt.xlim(0,)
plt.xlabel("t")
plt.ylabel(r"$u_{rms}$")
plt.show()

# %%
D = np.round(L0*u_ave/cs_d, 3)
display(Latex(fr'$D$ = {D}'))
# Out:
# $D$ = 0.025

# %% [markdown]
# ## reading yaver.dat

# %%
yaver = pc.read.aver(plane_list='y')
# Out:
# ['y'] ['yaver.in'] ['yaverages.dat']
# ['uzmxz', 'ssmxz']
# var_index -1
# var_index -1

# %% [markdown]
# ### We can notice that $u_{rms}$ saturates at around $t=100$, hence we will consider $u_z(t,x,z)$ after this $t$
# Here we have taken t=100

# %%
uz_real = yaver.y.uzmxz

# %%
size = np.shape(uz_real)
#size
nx = size[1]
nz = size[2]
nt = size[0]

tt = yaver.t

# %% [markdown]
# readding the parameters

# %%
param = pc.read.param()

# %%
lxyz = param.lxyz   #shape of the box
grz = -param.gravz  #value of g along z direction
cp = param.cp
lx = lxyz[0]
ly = lxyz[1]
lz = lxyz[2]
lz
# Out:
# 3.14159

# %%
indx_z_surf = 212    #selecting the plane to observe f-modes
indx_t1 = np.argmin(np.abs(tt - 170))  #to avoid the transient effects below t=170
indx_t2 = -1

# %%
t_gd = tt[indx_t1:indx_t2]  #time interval where urms has reached a steady state
t_len = np.size(t_gd)

dkx = 2*np.pi/lx    #unit step along kx direction
dom = 2*np.pi/t_len #unit step alomg omega direction

# %% [markdown]
# shape of the data

# %%
uz_real[indx_t1:indx_t2,:,indx_z_surf].shape
# Out:
# (1262, 400)

# %% [markdown]
# ### taking fourier transform of $u_z(t,x,z=0)$ to get $\hat{u}_z(\omega,k_x)$

# %%
uz_fourier = np.fft.fftn(uz_real[indx_t1:indx_t2,:,indx_z_surf], s=None, axes=(-2, -1), norm=None)

# %%
#uz_fourier[para_0, 2]

# %% [markdown]
# ### we can construct the dimensionless quantity
# $\tilde{P}(\omega,k_x)=\frac{|\hat{u}_z|}{D^2}$

# %%
logP = np.log(np.abs(uz_fourier/D**2))

# %% [markdown]
# ### defining $\tilde{k}_x=k_xL_0, \hspace{2mm} \tilde{\omega}=\frac{\omega}{\omega_0}$

# %%
if t_len%2 == 0:
    fom = np.arange(0, t_len/2+1)
    rom = -np.flip(np.arange(1, t_len/2))
    om = np.concatenate((fom, rom))*dom
else:
    fom = np.arange(0, t_len/2)
    rom = -np.flip(np.arange(1, t_len/2))
    om = np.concatenate((fom, rom))*dom

# %%
if nx%2 == 0:
    fnx = np.arange(0, nx/2+1)
    rnx = -np.flip(np.arange(1, nx/2))
    kx = np.concatenate((fnx, rnx))*dkx
else:
    fnx = np.arange(0, nx/2)
    rnx = -np.flip(np.arange(1, nx/2))
    kx = np.concatenate((fnx, rnx))*dkx

# %%
om.shape, kx.shape
# Out:
# ((1262,), (400,))

# %%
k_tilde = kx*L0
om_tilde = om/omega0
np.shape(om_tilde), np.shape(k_tilde), np.shape(logP)
# Out:
# ((1262,), (400,), (1262, 400))

# %% [markdown]
# ### plotting $\tilde{k}_x-\tilde{\omega}$ diagram

# %%
[X, Y] = np.meshgrid(k_tilde, om_tilde)
#plt.contourf(X, Y, logP, 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))
plt.contourf(np.fft.fftshift(X), np.fft.fftshift(Y), np.fft.fftshift(logP), 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))
#plt.plot(k_tilde, np.sqrt(grz*k_tilde), 'k')
plt.axvline(x=2, c='k')
plt.xlim(-10,10)
#plt.ylim(0,10)
plt.colorbar()
plt.xlabel(r"$\tilde{k_x}$")
plt.ylabel(r"$\tilde{\omega}$")
plt.show()
# Out:
# Locator attempting to generate 1120 ticks ([-5.745, ..., 11.04]), which exceeds Locator.MAXTICKS (1000).

# %%
idl = np.argmin(np.abs(om_tilde - 0)) 
idu = np.argmin(np.abs(om_tilde - np.pi))
# print(idu), print(idl)

fig, ax = plt.subplots()
[X, Y] = np.meshgrid(k_tilde[0:int(nx/2+1)], om_tilde[idl:idu])
#plt.contourf(X, Y, logP, 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))
cont = ax.contourf(np.fft.fftshift(X), np.fft.fftshift(Y), np.fft.fftshift(logP[idl:idu, 0:int(nx/2+1)]), 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))
#plt.plot(k_tilde, np.sqrt(grz*k_tilde), 'k')
plt.axvline(x=2, c='k')
plt.xlim(0,10)
#plt.ylim(0,10)
plt.colorbar(cont)
plt.xlabel(r"$\tilde{k_x}$")
plt.ylabel(r"$\tilde{\omega}$")
plt.show()
# Out:
# Locator attempting to generate 1034 ticks ([-4.455, ..., 11.04]), which exceeds Locator.MAXTICKS (1000).

# %% [markdown]
# ### finding $\tilde{P}(\tilde{\omega},\tilde{k}_x=2)$

# %%
P_k2 = np.abs(uz_fourier[:,2]/D**2)
P_k4 = np.abs(uz_fourier[:,4]/D**2)

# %%
kz = []
L_sd = np.pi*(5/6)*L0
for i in range(10):
    kz.append(np.pi*(i+0.5)/L_sd)

# %% [markdown]
# ### plotting $\tilde{P}(\tilde{\omega},\tilde{k_x}=2)$ as a function of $\tilde{\omega}$

# %%
fig, axs = plt.subplots(2,1, sharex=True, figsize=(16,8))

axs[0].plot(om_tilde, P_k2, label=r'with the line')
# for i in range(len(kz)):
#     plt.axvline(x = kz[i], color = 'b')
axs[0].set_xlim(0, np.pi)
axs[0].set_ylim(0,)
axs[0].legend()

axs[1].plot(np.fft.fftshift(om_tilde), np.fft.fftshift(P_k2), label=r'without the line')    # NOTE:Phere we have used the fftshift to 
axs[1].set_ylim(0,)                                                                         #Shift the zero-frequency component to the center of the spectrum

axs[1].legend()

plt.show()

# %%
fig, axs = plt.subplots(2,1, sharex=True, figsize=(16,8))

axs[0].plot(om_tilde[idl:idu], P_k2[idl:idu], label=r'$k_x=2$')
# for i in range(len(kz)):
#     plt.axvline(x = kz[i], color = 'b')
axs[0].set_xlim(0, np.pi)
axs[0].set_ylim(0,)
axs[0].legend()

axs[1].plot(om_tilde[idl:idu], P_k4[idl:idu], label=r'$k_x=4$')
axs[1].set_ylim(0,)
axs[1].legend()

plt.xlabel(r"$\tilde{\omega}$")
fig.supylabel(r"$\tilde{P}(\tilde{\omega})$")
plt.tight_layout
plt.show()

# %% [markdown]
# # fitting

# %%
fig = plt.figure(figsize=(16,4))

plt.plot(om_tilde[idl:idu], P_k2[idl:idu], label=r'$k_x=2$')

plt.axvline(x = 0.22, color = 'k')
plt.axvline(x = 0.33, color = 'k')
#plt.axvline(x = para_0[2], color = 'purple')

plt.axvline(x = 0.37, color = 'brown')
plt.axvline(x = 0.58, color = 'brown')

plt.axvline(x = 0.69, color = 'b')
plt.axvline(x = 0.83, color = 'b')

plt.axvline(x = 0.95, color = 'r')
plt.axvline(x = 1.14, color = 'r')

plt.axvline(x = 1.35, color = 'g')
plt.axvline(x = 1.61, color = 'g')

plt.axvline(x = 1.8, color = 'y')
plt.axvline(x = 2.05, color = 'y')

plt.axvline(x = 2.285, color = 'm')
plt.axvline(x = 2.56, color = 'm')

plt.axvline(x = 2.75, color = 'orange')
plt.axvline(x = 3.06, color = 'orange')

#plt.axvline(x = 0.652, color = 'pink')
#plt.axvline(x = 0.85, color = 'pink')

#plt.axvline(x = 1.07, color = 'brown')
#plt.axvline(x = 1.4, color = 'brown')



plt.xlim(0, np.pi)
plt.ylim(0,)
plt.legend()

plt.xlabel(r"$\tilde{\omega}$")
plt.ylabel(r"$\tilde{P}(\tilde{\omega})$")
plt.tight_layout
plt.show()

# %% [markdown]
# ### finding the index of the peaks

# %%
idl0 = np.argmin(np.abs(om_tilde - 0.22)) 
idu0 = np.argmin(np.abs(om_tilde - 0.33)) 

idl1 = np.argmin(np.abs(om_tilde - 0.37)) 
idu1 = np.argmin(np.abs(om_tilde - 0.58)) 

idl2 = np.argmin(np.abs(om_tilde - 0.69)) 
idu2 = np.argmin(np.abs(om_tilde - 0.83)) 

idl3 = np.argmin(np.abs(om_tilde - 0.91)) 
idu3 = np.argmin(np.abs(om_tilde - 1.18)) 

idl4 = np.argmin(np.abs(om_tilde - 1.35)) 
idu4 = np.argmin(np.abs(om_tilde - 1.61)) 

idl5 = np.argmin(np.abs(om_tilde - 1.80)) 
idu5 = np.argmin(np.abs(om_tilde - 2.10)) 

idl6 = np.argmin(np.abs(om_tilde - 2.20)) 
idu6 = np.argmin(np.abs(om_tilde - 2.65)) 

idl7 = np.argmin(np.abs(om_tilde - 2.66)) 
idu7 = np.argmin(np.abs(om_tilde - 3.12))

# %% [markdown]
# ### fitting indivisual peaks

# %%
def gauss(x, a, b, c, x0):
    y = a*np.exp(-1*b*(x-c)**2)+x0
    return y

para_0, cov_0 = curve_fit(gauss, om_tilde[idl0:idu0], P_k2[idl0:idu0], p0=[5000,80,0.28,500])
fitted_0 = gauss(om_tilde[idl0:idu0], *para_0)

para_1, cov_1 = curve_fit(gauss, om_tilde[idl1:idu1], P_k2[idl1:idu1], p0=[6000,20,0.45,500])
fitted_1 = gauss(om_tilde[idl1:idu1], *para_1)

para_2, cov_2 = curve_fit(gauss, om_tilde[idl2:idu2], P_k2[idl2:idu2], p0=[6000,20,0.75,0])
fitted_2 = gauss(om_tilde[idl2:idu2], *para_2)

# para_3, cov_3 = curve_fit(gauss, om_tilde[idl3:idu3], P_k2[idl3:idu3], p0=[6000,24,1.05])
# fitted_3 = gauss(om_tilde[idl3:idu3], *para_3)

# para_4, cov_4 = curve_fit(gauss, om_tilde[idl4:idu4], P_k2[idl4:idu4], p0=[6000,20,1.48])
# fitted_4 = gauss(om_tilde[idl4:idu4], *para_4)

# para_5, cov_5 = curve_fit(gauss, om_tilde[idl5:idu5], P_k2[idl5:idu5], p0=[6000,20,1.90])
# fitted_5 = gauss(om_tilde[idl5:idu5], *para_5)

# para_6, cov_6 = curve_fit(gauss, om_tilde[idl6:idu6], P_k2[idl6:idu6], p0=[6000,20,2.38])
# fitted_6 = gauss(om_tilde[idl6:idu6], *para_6)

# para_7, cov_7 = curve_fit(gauss, om_tilde[idl7:idu7], P_k2[idl7:idu7], p0=[6000,20,2.87])
# fitted_7 = gauss(om_tilde[idl7:idu7], *para_7)

# # para[0], para[1], para[2]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_2layer/py_file.ipynb Cell 63 line 8
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_2layer/py_file.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> para_0, cov_0 = curve_fit(gauss, om_tilde[idl0:idu0], P_k2[idl0:idu0], p0=[5000,80,0.28,500])
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_2layer/py_file.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> fitted_0 = gauss(om_tilde[idl0:idu0], *para_0)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_2layer/py_file.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> para_1, cov_1 = curve_fit(gauss, om_tilde[idl1:idu1], P_k2[idl1:idu1], p0=[6000,20,0.45,500])
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_2layer/py_file.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> fitted_1 = gauss(om_tilde[idl1:idu1], *para_1)
#      <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_2layer/py_file.ipynb#Y116sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> para_2, cov_2 = curve_fit(gauss, om_tilde[idl2:idu2], P_k2[idl2:idu2], p0=[6000,20,0.75,0])
#
# File ~/.conda/envs/env/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:968, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     966     cost = np.sum(infodict['fvec'] ** 2)
#     967     if ier not in [1, 2, 3, 4]:
# --> 968         raise RuntimeError("Optimal parameters not found: " + errmsg)
#     969 else:
#     970     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#     971     if 'max_nfev' not in kwargs:
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 1000.

# %% [markdown]
# ### plotting the fitted spectrum

# %%
fig = plt.figure(figsize=(16,4))

plt.plot(om_tilde[idl:idu], P_k2_filt[idl:idu], alpha=0.4)

plt.plot(om_tilde[idl0:idu0], fitted_0, color='k', label=fr'$\omega=${om_tilde[0]:.3f}')
plt.plot(om_tilde[idl1:idu1], fitted_1, color='brown', label=fr'$\omega=${om_tilde[1]:.3f}')
plt.plot(om_tilde[idl2:idu2], fitted_2, color='b', label=fr'$\omega=${om_tilde[2]:.3f}')
# plt.plot(om_tilde[idl3:idu3], fitted_3, color='r', label=fr'$\omega=${om_tilde[3]:.3f}')
# plt.plot(om_tilde[idl4:idu4], fitted_4, color='g', label=fr'$\omega=${om_tilde[4]:.3f}')
# plt.plot(om_tilde[idl5:idu5], fitted_5, color='y', label=fr'$\omega=${om_tilde[5]:.3f}')
# plt.plot(om_tilde[idl6:idu6], fitted_6, color='m', label=fr'$\omega=${om_tilde[6]:.3f}')
# plt.plot(om_tilde[idl7:idu7], fitted_7, color='orange', label=fr'$\omega=${om_tilde[7]:.3f}')

plt.xlim(0, np.pi)
plt.ylim(0,)
plt.legend(bbox_to_anchor=[1,1], loc='best')

plt.xlabel(r"$\tilde{\omega}$")
plt.ylabel(r"$\tilde{P}(\tilde{\omega})$")
#plt.tight_layout
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb Cell 65 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> fig = plt.figure(figsize=(16,4))
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.plot(om_tilde[idl:idu], P_k2_filt[idl:idu], alpha=0.4)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.plot(om_tilde[idl0:idu0], fitted_0, color='k', label=fr'$\omega=${om_tilde[0]:.3f}')
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> plt.plot(om_tilde[idl1:idu1], fitted_1, color='brown', label=fr'$\omega=${om_tilde[1]:.3f}')
#
# NameError: name 'P_k2_filt' is not defined

# %% [markdown]
# ## evaluating eigenfunctions

# %% [markdown]
# ### calculating $\hat{u}_z(\omega,k_x, z)$ for different values of $z$

# %%
indx_z = np.arange(0, 256, 2)
indx_z = np.linspace(-2.6179, 0.52359, 256)

for i in range(len(indx_z)):
    # exec(f'uz_fourier_{i} = np.fft.fftn(uz_real[indx_t1:indx_t2,:,indx_z[{i}]], s=None, axes=(-2, -1), norm=None)')
    exec(f'uz_fourier_{i} = np.fft.fftn(uz_real[indx_t1:indx_t2,:,{i}], s=None, axes=(-2, -1), norm=None)')

# %% [markdown]
# ### calculating the indexes i.e. the tuple $(\tilde{\omega}, \tilde{k}_x)$ for different modes

# %%
labels = []

for i in range(8):
    exec(f'id_om_{i} = np.argmin(np.abs(om_tilde - para_{i}[2]))')
    exec(f'labels.append(para_{i})')

id_kx = np.argmin(np.abs(k_tilde - 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb Cell 70 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> labels = []
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> for i in range(8):
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     exec(f'id_om_{i} = np.argmin(np.abs(om_tilde - para_{i}[2]))')
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     exec(f'labels.append(para_{i})')
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> id_kx = np.argmin(np.abs(k_tilde - 2))
#
# File <string>:1
#
# NameError: name 'para_3' is not defined

# %% [markdown]
# ### calculating the array to plot eigenfunctions of different modes

# %%
array = np.zeros((len(indx_z), 8), dtype='complex') # NOTE: for k_x=2 (tilde) we have found 8 modes.

for i in range(np.size(array, 0)):
    for j in range(np.size(array, 1)):
        exec(f'array[i,j] = uz_fourier_{i}[id_om_{j}, id_kx]')

# %% [markdown]
# ### plotting eigenfunctions

# %%
fig, axs = plt.subplots(1,2, figsize=(14,5))
ls = ['-', ':', '--', '-.', (0, (5, 10)), (0, (3, 10, 1, 10)), (5, (10, 3)), (0, (3, 1, 1, 1, 1, 1))]

for i in range(np.size(array, 1)):
    exec(f'temp = id_om_{i}')
    # axs[0].plot(indx_z, np.real(array[:,i]), label=fr'$\omega=$om_tilde[id_om_{i}]')
    axs[0].plot(indx_z, np.real(array[:,i]), ls=ls[i])
    axs[1].plot(indx_z, np.imag(array[:,i]), ls=ls[i], label=fr'$\omega=${om_tilde[temp]:.3f}')#, label=f'id_om_{i}')

axs[0].axvline(x=0, c='k', ls='--')
axs[0].set_xlim(indx_z[0], indx_z[-1])
# axs[0].set_ylim(0,)
# axs[0].legend()
axs[0].set_title(r"real")
axs[0].set_xlabel(r"$z$")

axs[1].axvline(x=0, c='k', ls='--')
axs[1].set_xlim(indx_z[0], indx_z[-1])
# axs[1].set_ylim(0,)
axs[1].legend(bbox_to_anchor=[1.03,0.5], loc='center left')
axs[1].set_title(r"imaginary")
axs[1].set_xlabel(r"$z$")

fig.supylabel(r"$\hat{u}_z$")
plt.suptitle(r'for $k_x=2$')
plt.tight_layout()
plt.show()

# %%
P_k2_filt = gaussian_filter1d(P_k2[idl:idu],0.8)

# %%
fig = plt.figure(figsize=(16,4))

plt.plot(om_tilde[idl:idu], P_k2[idl:idu], alpha=1., label = "un-filttered")
plt.plot(om_tilde[idl:idu], P_k2_filt[idl:idu], alpha=1., label = "filttered")

plt.xlim(0, np.pi)
plt.ylim(0,)
plt.legend(bbox_to_anchor=[1,1], loc='best')
plt.xlabel(r"$\tilde{\omega}$")
plt.ylabel(r"$\tilde{P}(\tilde{\omega})$")
plt.show()

# %%
idl0 = np.argmin(np.abs(om_tilde - 0.22)) 
idl0, para_0[2]
# Out:
# (28, 0.2776926037475648)

# %%
def gauss(x, a, b, c, x0):
    y = a*np.exp(-1*b*(x-c)**2)+x0
    return y

initial = [[6000,80,0.28,1000], [6000,20,0.45,1000], [6000,20,0.75,1000], [6000,24,1.05,1000], [6000,20,1.48,1000], [6000,20,1.90,1000], [6000,20,2.38,1000], [6000,20,2.87,1000]]

for i in range(8):
    exec(f"para_{i}, cov_{i} = curve_fit(gauss, om_tilde[idl{i}:idu{i}], P_k2_filt[idl{i}:idu{i}], initial[{i}])")
    exec(f"ox_{i} = np.linspace(om_tilde[idl{i}],om_tilde[idu{i}],200)")
    exec(f"fitted_{i} = gauss(ox_{i}, *para_{i})")

# %%
idl0 = np.argmin(np.abs(om_tilde - 0.22)) 
idu0 = np.argmin(np.abs(om_tilde - 0.38)) 

idl1 = np.argmin(np.abs(om_tilde - 0.37)) 
idu1 = np.argmin(np.abs(om_tilde - 0.58)) 

idl2 = np.argmin(np.abs(om_tilde - 0.69)) 
idu2 = np.argmin(np.abs(om_tilde - 0.83)) 

idl3 = np.argmin(np.abs(om_tilde - 0.91)) 
idu3 = np.argmin(np.abs(om_tilde - 1.18)) 

idl4 = np.argmin(np.abs(om_tilde - 1.35)) 
idu4 = np.argmin(np.abs(om_tilde - 1.61)) 

idl5 = np.argmin(np.abs(om_tilde - 1.80)) 
idu5 = np.argmin(np.abs(om_tilde - 2.10)) 

idl6 = np.argmin(np.abs(om_tilde - 2.20)) 
idu6 = np.argmin(np.abs(om_tilde - 2.65)) 

idl7 = np.argmin(np.abs(om_tilde - 2.66)) 
idu7 = np.argmin(np.abs(om_tilde - 3.12)) 


l = 0.08
u = 0.08
for i in range(8):
    exec(f"idl{i} = np.argmin(np.abs(om_tilde - para_{i}[2]+l))")
    exec(f"idu{i} = np.argmin(np.abs(om_tilde - para_{i}[2]-u))")

idl0, P_k2_filt[idl0]
# Out:
# (26, 2813.5816839324007)

# %%
fig, axs = plt.subplots(4,4, figsize=(16,4))

# plt.plot(om_tilde[idl:idu], P_k2_filt[idl:idu], alpha=0.4)

for i in range(8):
    axs[0,0].plot(om_tilde[idl:idu], P_k2_filt[idl:idu], alpha=0.4)
    axs[0,0].plot(om_tilde[idl0:idu0], fitted_0, color='k', label=fr'$\omega=${om_tilde[0]:.3f}')
# axs[].plot(om_tilde[idl1:idu1], fitted_1, color='brown', label=fr'$\omega=${om_tilde[1]:.3f}')
# axs[].plot(om_tilde[idl2:idu2], fitted_2, color='b', label=fr'$\omega=${om_tilde[2]:.3f}')
# axs[].plot(om_tilde[idl3:idu3], fitted_3, color='r', label=fr'$\omega=${om_tilde[3]:.3f}')
# axs[].plot(om_tilde[idl4:idu4], fitted_4, color='g', label=fr'$\omega=${om_tilde[4]:.3f}')
# axs[].plot(om_tilde[idl5:idu5], fitted_5, color='y', label=fr'$\omega=${om_tilde[5]:.3f}')
# axs[].plot(om_tilde[idl6:idu6], fitted_6, color='m', label=fr'$\omega=${om_tilde[6]:.3f}')
# axs[].plot(om_tilde[idl7:idu7], fitted_7, color='orange', label=fr'$\omega=${om_tilde[7]:.3f}')

plt.xlim(0, np.pi)
plt.ylim(0,)
plt.legend(bbox_to_anchor=[1,1], loc='best')

plt.xlabel(r"$\tilde{\omega}$")
plt.ylabel(r"$\tilde{P}(\tilde{\omega})$")
#plt.tight_layout
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb Cell 81 line 7
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> for i in range(8):
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     axs[0,0].plot(om_tilde[idl:idu], P_k2_filt[idl:idu], alpha=0.4)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     axs[0,0].plot(om_tilde[idl0:idu0], fitted_0, color='k', label=fr'$\omega=${om_tilde[0]:.3f}')
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> # axs[].plot(om_tilde[idl1:idu1], fitted_1, color='brown', label=fr'$\omega=${om_tilde[1]:.3f}')
#       <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # axs[].plot(om_tilde[idl2:idu2], fitted_2, color='b', label=fr'$\omega=${om_tilde[2]:.3f}')
#      <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # axs[].plot(om_tilde[idl3:idu3], fitted_3, color='r', label=fr'$\omega=${om_tilde[3]:.3f}')
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> # axs[].plot(om_tilde[idl6:idu6], fitted_6, color='m', label=fr'$\omega=${om_tilde[6]:.3f}')
#      <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> # axs[].plot(om_tilde[idl7:idu7], fitted_7, color='orange', label=fr'$\omega=${om_tilde[7]:.3f}')
#      <a href='vscode-notebook-cell://ssh-remote%2Bpegasus/scratch/cmondal/pc_data/dynamo_modes/test_dir/mag_n7_16x16xpi/py_file.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> plt.xlim(0, np.pi)
#
# File ~/.conda/envs/env/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/.conda/envs/env/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.conda/envs/env/lib/python3.11/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (20,) and (200,)

# %%
fig, axs = plt.subplots(2,4, figsize=(20,10))
for i, ax in enumerate(axs.flat):
    exec(f"ax.plot(om_tilde[idl{i}:idu{i}], P_k2_filt[idl{i}:idu{i}], alpha=0.4)")
    exec(f"ax.plot(ox_{i}, fitted_{i}, color='k', ls=':', label=fr'$\omega=${om_tilde[0]:.3f}')")

# %%
plt.plot(om_tilde[idl0:idu0], P_k2_filt[idl0:idu0], alpha=0.4)
plt.plot(ox_0, fitted_0, color='k', ls=':', label=fr'$\omega=${om_tilde[0]:.3f}')
