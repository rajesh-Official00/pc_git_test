# %%
import numpy as np
import matplotlib.pyplot as plt
import pencil as pc
from IPython.display import display, Math, Latex
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 import pencil as pc
#       4 from IPython.display import display, Math, Latex
#
# File ~/miniconda3/envs/env_pencil/lib/python3.11/site-packages/matplotlib/pyplot.py:56
#      54 from cycler import cycler
#      55 import matplotlib
# ---> 56 import matplotlib.colorbar
#      57 import matplotlib.image
#      58 from matplotlib import _api
#
# File ~/miniconda3/envs/env_pencil/lib/python3.11/site-packages/matplotlib/colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File ~/miniconda3/envs/env_pencil/lib/python3.11/site-packages/matplotlib/collections.py:20
#      17 import numpy as np
#      19 import matplotlib as mpl
# ---> 20 from . import (_api, _path, artist, cbook, cm, colors as mcolors, _docstring,
#      21                hatch as mhatch, lines as mlines, path as mpath, transforms)
#      22 from ._enums import JoinStyle, CapStyle
#      25 # "color" is excluded; it is a compound setter, and its docstring differs
#      26 # in LineCollection.
#
# File ~/miniconda3/envs/env_pencil/lib/python3.11/site-packages/matplotlib/lines.py:17
#      14 from .artist import Artist, allow_rasterization
#      15 from .cbook import (
#      16     _to_unmasked_float_array, ls_mapper, ls_mapper_r, STEP_LOOKUP_MAP)
# ---> 17 from .markers import MarkerStyle
#      18 from .path import Path
#      19 from .transforms import Bbox, BboxTransformTo, TransformedPath
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1131, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
np.flip(np.arange(1, 20/2))
# Out:
# array([9., 8., 7., 6., 5., 4., 3., 2., 1.])

# %%
# data = np.loadtxt('stratification.dat')

# %%
# plt.plot(data[:,0], data[:,1])
# plt.plot(data[:,0], data[:,2])
# plt.xlim(-0.9*np.pi, 0.1*np.pi)
# # plt.yscale('log')

# %%
#reading the grid
grid = pc.read.grid(trim=True, quiet=True)
z = grid.z

# %%
ts = pc.read.ts()
# Out:
# Read 8952 lines.

# %%
ts5a = pc.read.ts(datadir='/scratch/cmondal/pc_data/dynamo_modes/test_dir/modes/with_2layer_cooling/magnetic/2layer_mod5a/data')
# Out:
# Read 15322 lines.

# %%
xx = np.average(ts.urms[1000:5000])

# %%
plt.figure(figsize=(6,2.5))
plt.plot(ts.t, ts.urms)
plt.plot(ts5a.t, ts5a.urms, alpha=0.4)
# plt.xlim(ts.t[0], ts.t[-1])
plt.axhline(y=xx, ls=':', c='k')
plt.axvline(x=1000, ls=':', c='k')
plt.ylim(0, )
plt.xlabel("t")
plt.ylabel(r"$u_{rms}$")
plt.show()

# %%
plt.plot(ts.t, ts.Rmesh)

# %%
plt.plot(ts.t, ts.rhom)

# %%
ts.urms[-1]
# Out:
# 0.156

# %%
plt.figure(figsize=(6,2.5))
plt.plot(ts.t, ts.brms)
plt.xlim(ts.t[0], ts.t[-1])
plt.yscale('log')
plt.xlabel("t")
plt.ylabel(r"$b_{rms}$")
plt.show()

# %%
def ave_b(tt):
    it = np.argmin(np.abs(xya.t - tt))
    return xya.xy.bx2mz[it,:]/np.average(xya.xy.bx2mz[it,:])

# %%
# plt.plot(z, ave_b(1000), label='1000')
# plt.plot(z, ave_b(1400), label='1400')
# plt.plot(z, ave_b(2500), label='2500')
# plt.legend()

# %%
src_datadir = "./data"
src_var = "var.dat"
var = pc.read.var(var_file=src_var, datadir=src_datadir, trimall=True)
# f = var.f

# %%
grid.x
# Out:
# array([-18.831148, -18.794333, -18.757517, ...,  18.757517,  18.794333,
#         18.831148], dtype=float32)

# %%
print(var.magic)
# Out:
# None

# %%
var.keys()
# Out:
# t
# dx
# dy
# dz
# x
# y
# z
# f
# l1
# l2
# m1
# m2
# n1
# n2
# magic
# uu
# ux
# uy
# uz
# lnrho
# ss
# aa
# ax
# ay
# az

# %%
f = var.f

# %%
np.shape(f)
# Out:
# (8, 256, 256, 1024)

# %%
f[3]
# Out:
# array([[[ 5.1830017 ,  5.21690295,  5.2282827 , ...,  5.19299514,
#           5.1894248 ,  5.16240927],
#         [ 5.17879567,  5.1949351 ,  5.20125203, ...,  5.17461661,
#           5.1738002 ,  5.15011349],
#         [ 5.1846538 ,  5.18200396,  5.19370606, ...,  5.15513842,
#           5.15189428,  5.14225852],
#         ...,
#         [ 5.18539424,  5.2147206 ,  5.24680909, ...,  5.24719418,
#           5.24882624,  5.22043536],
#         [ 5.17555959,  5.20946855,  5.23462015, ...,  5.23208533,
#           5.22945488,  5.20059286],
#         [ 5.17771813,  5.21233577,  5.23349847, ...,  5.2130537 ,
#           5.20430849,  5.18103033]],
#
#        [[ 5.1292502 ,  5.14201139,  5.15040014, ...,  5.1413371 ,
#           5.14038656,  5.12632424],
#         [ 5.12373409,  5.12653062,  5.13233797, ...,  5.13006811,
#           5.13051189,  5.11659382],
#         [ 5.12642344,  5.11899444,  5.12812066, ...,  5.11892348,
#           5.11758044,  5.11106229],
#         ...,
#         [ 5.14023752,  5.14863016,  5.16979345, ...,  5.17555505,
#           5.17657697,  5.1678924 ],
#         [ 5.13053695,  5.14342451,  5.1595813 , ...,  5.16591078,
#           5.16487946,  5.15358045],
#         [ 5.12888481,  5.14292447,  5.15652036, ...,  5.15406077,
#           5.14943983,  5.13929265]],
#
#        [[ 5.08938814,  5.09302336,  5.10053983, ...,  5.10745585,
#           5.10841071,  5.09974185],
#         [ 5.08257301,  5.07910008,  5.0851802 , ...,  5.10028608,
#           5.10267415,  5.09344327],
#         [ 5.08486473,  5.07396482,  5.08287631, ...,  5.09333863,
#           5.09414379,  5.09027725],
#         ...,
#         [ 5.10157637,  5.10467845,  5.12092366, ...,  5.13102916,
#           5.13297494,  5.12786234],
#         [ 5.09251015,  5.09782388,  5.10981405, ...,  5.12542271,
#           5.12542446,  5.11792755],
#         [ 5.09059025,  5.09594545,  5.10644703, ...,  5.1167988 ,
#           5.11374462,  5.10721395]],
#
#        ...,
#
#        [[-1.57985064, -1.57882269, -1.57758289, ..., -1.5783649 ,
#          -1.57876631, -1.57983794],
#         [-1.57852703, -1.57733404, -1.57625038, ..., -1.57704975,
#          -1.57736502, -1.57845045],
#         [-1.57738284, -1.57629876, -1.57531216, ..., -1.57545481,
#          -1.5757435 , -1.57695508],
#         ...,
#         [-1.5848653 , -1.58428471, -1.58239529, ..., -1.58221204,
#          -1.58283478, -1.58411891],
#         [-1.58304411, -1.58260507, -1.58093005, ..., -1.58077136,
#          -1.58129578, -1.58243881],
#         [-1.58140404, -1.58072967, -1.57928402, ..., -1.57955706,
#          -1.58004152, -1.58113176]],
#
#        [[-1.58068924, -1.57935579, -1.5779151 , ..., -1.58006335,
#          -1.58000119, -1.58094921],
#         [-1.57933236, -1.57783676, -1.57656399, ..., -1.57867104,
#          -1.57851403, -1.57943438],
#         [-1.57803609, -1.57672868, -1.57557567, ..., -1.57688639,
#          -1.57677546, -1.57776723],
#         ...,
#         [-1.58588136, -1.58508673, -1.58278961, ..., -1.58392855,
#          -1.58424802, -1.58533015],
#         [-1.58396163, -1.58330422, -1.58121631, ..., -1.58236941,
#          -1.58265075, -1.58363952],
#         [-1.58225897, -1.5813239 , -1.57957859, ..., -1.58122934,
#          -1.58137528, -1.58232921]],
#
#        [[-1.59085569, -1.58941128, -1.58719812, ..., -1.58719978,
#          -1.58834309, -1.59085256],
#         [-1.58960811, -1.58770935, -1.58590104, ..., -1.58563363,
#          -1.58646481, -1.58924035],
#         [-1.58833725, -1.5865297 , -1.58482229, ..., -1.58328586,
#          -1.58405158, -1.58711712],
#         ...,
#         [-1.59495083, -1.59391704, -1.5905349 , ..., -1.59045005,
#          -1.59137766, -1.59354732],
#         [-1.59359138, -1.59310039, -1.58993144, ..., -1.58927994,
#          -1.59040242, -1.59240226],
#         [-1.59225803, -1.59151397, -1.58874545, ..., -1.58825297,
#          -1.58958569, -1.59177664]]])

# %%
(var.lnrho)
# Out:
# array([[[ 5.1830017 ,  5.21690295,  5.2282827 , ...,  5.19299514,
#           5.1894248 ,  5.16240927],
#         [ 5.17879567,  5.1949351 ,  5.20125203, ...,  5.17461661,
#           5.1738002 ,  5.15011349],
#         [ 5.1846538 ,  5.18200396,  5.19370606, ...,  5.15513842,
#           5.15189428,  5.14225852],
#         ...,
#         [ 5.18539424,  5.2147206 ,  5.24680909, ...,  5.24719418,
#           5.24882624,  5.22043536],
#         [ 5.17555959,  5.20946855,  5.23462015, ...,  5.23208533,
#           5.22945488,  5.20059286],
#         [ 5.17771813,  5.21233577,  5.23349847, ...,  5.2130537 ,
#           5.20430849,  5.18103033]],
#
#        [[ 5.1292502 ,  5.14201139,  5.15040014, ...,  5.1413371 ,
#           5.14038656,  5.12632424],
#         [ 5.12373409,  5.12653062,  5.13233797, ...,  5.13006811,
#           5.13051189,  5.11659382],
#         [ 5.12642344,  5.11899444,  5.12812066, ...,  5.11892348,
#           5.11758044,  5.11106229],
#         ...,
#         [ 5.14023752,  5.14863016,  5.16979345, ...,  5.17555505,
#           5.17657697,  5.1678924 ],
#         [ 5.13053695,  5.14342451,  5.1595813 , ...,  5.16591078,
#           5.16487946,  5.15358045],
#         [ 5.12888481,  5.14292447,  5.15652036, ...,  5.15406077,
#           5.14943983,  5.13929265]],
#
#        [[ 5.08938814,  5.09302336,  5.10053983, ...,  5.10745585,
#           5.10841071,  5.09974185],
#         [ 5.08257301,  5.07910008,  5.0851802 , ...,  5.10028608,
#           5.10267415,  5.09344327],
#         [ 5.08486473,  5.07396482,  5.08287631, ...,  5.09333863,
#           5.09414379,  5.09027725],
#         ...,
#         [ 5.10157637,  5.10467845,  5.12092366, ...,  5.13102916,
#           5.13297494,  5.12786234],
#         [ 5.09251015,  5.09782388,  5.10981405, ...,  5.12542271,
#           5.12542446,  5.11792755],
#         [ 5.09059025,  5.09594545,  5.10644703, ...,  5.1167988 ,
#           5.11374462,  5.10721395]],
#
#        ...,
#
#        [[-1.57985064, -1.57882269, -1.57758289, ..., -1.5783649 ,
#          -1.57876631, -1.57983794],
#         [-1.57852703, -1.57733404, -1.57625038, ..., -1.57704975,
#          -1.57736502, -1.57845045],
#         [-1.57738284, -1.57629876, -1.57531216, ..., -1.57545481,
#          -1.5757435 , -1.57695508],
#         ...,
#         [-1.5848653 , -1.58428471, -1.58239529, ..., -1.58221204,
#          -1.58283478, -1.58411891],
#         [-1.58304411, -1.58260507, -1.58093005, ..., -1.58077136,
#          -1.58129578, -1.58243881],
#         [-1.58140404, -1.58072967, -1.57928402, ..., -1.57955706,
#          -1.58004152, -1.58113176]],
#
#        [[-1.58068924, -1.57935579, -1.5779151 , ..., -1.58006335,
#          -1.58000119, -1.58094921],
#         [-1.57933236, -1.57783676, -1.57656399, ..., -1.57867104,
#          -1.57851403, -1.57943438],
#         [-1.57803609, -1.57672868, -1.57557567, ..., -1.57688639,
#          -1.57677546, -1.57776723],
#         ...,
#         [-1.58588136, -1.58508673, -1.58278961, ..., -1.58392855,
#          -1.58424802, -1.58533015],
#         [-1.58396163, -1.58330422, -1.58121631, ..., -1.58236941,
#          -1.58265075, -1.58363952],
#         [-1.58225897, -1.5813239 , -1.57957859, ..., -1.58122934,
#          -1.58137528, -1.58232921]],
#
#        [[-1.59085569, -1.58941128, -1.58719812, ..., -1.58719978,
#          -1.58834309, -1.59085256],
#         [-1.58960811, -1.58770935, -1.58590104, ..., -1.58563363,
#          -1.58646481, -1.58924035],
#         [-1.58833725, -1.5865297 , -1.58482229, ..., -1.58328586,
#          -1.58405158, -1.58711712],
#         ...,
#         [-1.59495083, -1.59391704, -1.5905349 , ..., -1.59045005,
#          -1.59137766, -1.59354732],
#         [-1.59359138, -1.59310039, -1.58993144, ..., -1.58927994,
#          -1.59040242, -1.59240226],
#         [-1.59225803, -1.59151397, -1.58874545, ..., -1.58825297,
#          -1.58958569, -1.59177664]]])

# %%
xya = pc.read.aver(plane_list="xy")
pre = xya.xy.ppmz
rho = xya.xy.rhomz
tem = xya.xy.TTmz

# %%
data = np.loadtxt('stratification.dat')

# %%
# cp

# %%
from scipy.integrate import trapezoid

# %%
# ss = trapezoid(data[:,2], data[:,0])*gamma/cp
# TT = np.exp(ss)

# %%
fig, axs = plt.subplots(3,1, figsize=(6,4), sharex=True)

axs[0].plot(z, rho[-1,:], color='k')
axs[1].plot(z, pre[-1,:], color='k')
axs[2].plot(z, tem[-1,:], color='k')
# axs[2].plot(z, data[:,2], color='r')
# axs[2].plot(z, np.exp(data[:,2]*gamma/cp), color='b')
# axs[2].plot(z, TT, color='b')
# axs[2].plot(z, tem[-200,:], color='k')
for i in range(0,3):
    axs[i].axvline(x=0, c='r', ls=':')

axs[0].set_yscale("log")
axs[1].set_yscale("log")
axs[1].set_xlim(z[0], z[-1])
axs[0].set_ylabel(r"$\rho(z)$")
axs[1].set_ylabel(r"$P(z)$")
axs[2].set_ylabel(r"$T(z)$")
# axs[2].set_ylim(0,2)

plt.xlabel(r"$z/L_0$")
plt.tight_layout()
#plt.savefig("variation.jpg")

# %%
X = np.array([grid.z, rho[-1,:], pre[-1,:], tem[-1,:]])
X.T.shape
# Out:
# (256, 4)

# %%
np.savetxt('bg_data', X.T, header="z, rho, pres, temp")
data = np.loadtxt('bg_data')

# %%
fig, axs = plt.subplots(3,1, figsize=(6,4), sharex=True)

axs[0].plot(z, data[:,1], color='k')
axs[1].plot(z, data[:,2], color='k')
axs[2].plot(z, data[:,3], color='k')
# axs[0].axhline(y=0, c='r')

axs[0].set_yscale("log")
axs[1].set_yscale("log")
axs[1].set_xlim(z[0], z[-1])
axs[0].set_ylabel(r"$\rho(z)$")
axs[1].set_ylabel(r"$P(z)$")
axs[2].set_ylabel(r"$T(z)$")
axs[0].grid()
plt.show()

# %%
param = pc.read.param()

# %%
param.gravz, param.gamma
# Out:
# (-1.0, 1.6666666666666667)

# %%
grid.dz
# Out:
# 0.012319971190548208

# %%
gz = param.gravz
gamma = param.gamma
cp = param.cp
R = cp*(1-(1/gamma))

# %%
R
# Out:
# 0.4

# %%
xyaver = pc.read.aver(plane_list='xy')

# %%
xyaver.xy.keys
# Out:
# ['bxmz', 'bymz', 'bx2mz', 'by2mz', 'rhomz', 'TTmz', 'ppmz', 'ssmz', 't']

# %%
bxz0 = (xyaver.xy.bxmz/np.sqrt(xyaver.xy.bx2mz)).T

# %%
xyaver.t.shape
# Out:
# (4245,)

# %%
bxz0.shape
# Out:
# (256, 4245)

# %%
xya.xy.t
# Out:
# array([0.00000e+00, 3.42269e-01, 6.94365e-01, ..., 1.55033e+03,
#        1.55069e+03, 1.55104e+03], dtype=float32)

# %%
# z

# %%
bxmz=xya.xy.bxmz
bx2mz=xya.xy.bx2mz
bymz=xya.xy.bymz
by2mz=xya.xy.by2mz

bxmz_n=bxmz/np.sqrt(bx2mz)
bymz_n=bymz/np.sqrt(by2mz)

X, Y = np.meshgrid(xya.xy.t, z)

fig, axs = plt.subplots(2,1, figsize=(10,5))
axs[0].contourf(X, Y, np.transpose(bxmz_n),100,cmap='bwr')
axs[1].contourf(X, Y, np.transpose(bymz_n),100,cmap='bwr')
plt.xlabel(r'$t$')
plt.ylabel(r'$z$')
# plt.colorbar()
plt.tight_layout()

plt.show()

# %%
# plt.contourf(bxz0)

# %%
plt.plot(z, xyaver.xy.bx2mz[3500])
plt.plot(z, xyaver.xy.bx2mz[-1])
plt.xlim(z[0], z[-1])
# Out:
# (-2.8274333477020264, 0.3141592741012573)

# %%
yaver = pc.read.aver(plane_list='y')

# %%
uz_real = yaver.y.uzmxz

# %%
uz_real.shape
# Out:
# (53224, 1024, 256)

# %%
indx_t1 = np.argmin(np.abs(yaver.t - 15))  #to avoid the transient effects below t=40
indx_t2 = np.argmin(np.abs(yaver.t - yaver.t[-1]))

# %%
np.shape(yaver.t)
# Out:
# (53224,)

# %%
# uz_fourier = mode.FT(uz_real[indx_t1:indx_t2,:,mode.indx_zref], 'ortho')

# %%
uz_fourier = np.fft.fftn(uz_real[indx_t1:indx_t2,:,225], s=None, axes=(-2, -1), norm='ortho')
uz_fourier.shape
# Out:
# (52923, 1024)

# %%
D = 0.17662
logP = np.log(np.abs(uz_fourier)/D**2)

# %%
size = np.shape(uz_real)
#size
nx = size[1]
nz = size[2]
nt = size[0]

tt = yaver.t
len(grid.x)
# Out:
# 1024

# %%
param = pc.read.param()

# %%
lxyz = param.lxyz   #shape of the box
grz = -param.gravz  #value of g along z direction
gamma = param.gamma
cp = param.cp
lx = lxyz[0]
ly = lxyz[1]
lz = lxyz[2]
lz
# Out:
# 3.141592653589793

# %%
t_gd = tt[indx_t1:indx_t2]  #time interval where urms has reached a steady state
T = np.max(t_gd)-np.min(t_gd)
t_len = np.size(t_gd)

dkx = 2*np.pi/lx    #unit step along kx direction
dom = 2*np.pi/T #unit step alomg omega direction

# %%
if t_len%2 == 0:
    fom = np.arange(0, t_len/2)
    rom = -np.flip(np.arange(1, t_len/2+1))
    om = np.concatenate((fom, rom))*dom
else:
    fom = np.arange(0, t_len/2)
    rom = -np.flip(np.arange(1, t_len/2))
    om = np.concatenate((fom, rom))*dom

# %%
if nx%2 == 0:
    fnx = np.arange(0, nx/2)
    rnx = -np.flip(np.arange(1, nx/2+1))
    kx = np.concatenate((fnx, rnx))*dkx
else:
    fnx = np.arange(0, nx/2)
    rnx = -np.flip(np.arange(1, nx/2))
    kx = np.concatenate((fnx, rnx))*dkx

# %%
k_tilde = np.fft.fftshift(kx)#*L0
om_tilde = np.fft.fftshift(om)#/omega0
np.shape(om_tilde), np.shape(k_tilde), np.shape(logP)
# k_tilde
# Out:
# ((52923,), (1024,), (52923, 1024))

# %%
k_tilde
# Out:
# array([-85.33333333, -85.16666667, -85.        , ...,  84.83333333,
#         85.        ,  85.16666667])

# %%
om_tilde
# Out:
# array([-62.83184496, -62.82947045, -62.82709594, ...,  62.82709594,
#         62.82947045,  62.83184496])

# %%
cs_u = 3.154
cs_d = 1.008

# %%
X, Y = np.meshgrid(k_tilde, om_tilde)
plt.imshow(np.fft.fftshift(logP), vmin=np.min(logP), vmax=np.max(logP))

# %%
# [X, Y] = np.meshgrid(k_tilde, om_tilde)
# #plt.contourf(X, Y, logP, 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))
# # plt.contourf(np.fft.fftshift(X), np.fft.fftshift(Y), np.fft.fftshift(logP), 4000, cmap='afmhot_r', vmin=np.min(logP), vmax=np.max(logP))
# # plt.contourf(np.fft.fftshift(X), np.fft.fftshift(Y), np.fft.fftshift(logP), 4000, cmap='afmhot_r', vmin=-6, vmax=np.max(logP))
# # plt.contourf(X, Y, np.fft.fftshift(logP), 4000, cmap='afmhot_r', vmin=np.min(logP), vmax=np.max(logP))
# plt.contourf(X, Y, np.fft.fftshift(logP), 4000, cmap='afmhot_r', vmin=-4, vmax=np.max(logP))
# # plt.plot(aa, np.sqrt(grz*aa), ls='dashdot', c='k')
# # plt.plot(k_tilde, cs_d*k_tilde, ls='-', c='k')
# # plt.plot(k_tilde, cs_u*k_tilde, ls=':', c='k')
# plt.axvline(x=0, c='k', ls='--', lw=1)
# plt.axhline(y=0, c='k', ls='--', lw=1)
# plt.xlim(-2*np.pi,2*np.pi)
# plt.ylim(-2*np.pi,2*np.pi)
# #plt.ylim(0,10)
# plt.colorbar()
# plt.xlabel(r"$\tilde{k}_x$")
# plt.ylabel(r"$\tilde{\omega}$")
# # plt.savefig('plots/k_om.png')
# plt.show()

# %%
def pmodes(kx, n: int):
        """
        Calculate the freq of p-mode.
        n: order of p-modes, 0, 1, 2, 3, ...
        """
        gz = 1
        L0 = 1
        omega0 = 1
        om_sq = gz**2/(2*cs_d)**2+cs_d**2*((kx/L0)**2+((n+0.5)*np.pi/(9*lz/10))**2)
        freq = np.sqrt(om_sq/omega0**2)
        return np.round(freq, 3)

def fmode(kx):
        gz = 1
        om_sq = gz*kx
        omega0 = 1
        freq = np.sqrt(om_sq/omega0**2)
        return np.round(freq, 3)

# %%
gz = 1
L0 = 1
omega0 = 1

# %%
# k_tilde[0:512]
# k_tilde[512:-1]

# %%
[X, Y] = np.meshgrid(k_tilde, om_tilde)
#plt.contourf(X, Y, logP, 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))
# plt.contourf(np.fft.fftshift(X), np.fft.fftshift(Y), np.fft.fftshift(logP), 4000, cmap='afmhot_r', vmin=np.min(logP), vmax=np.max(logP))
plt.contourf(X, Y, np.fft.fftshift(logP), 4000, cmap='afmhot_r', vmin=-6, vmax=np.max(logP))
# plt.plot(aa, np.sqrt(grz*aa), ls='dashdot', c='k')
# plt.plot(k_tilde, cs_d*k_tilde, ls='-', c='k')
# plt.plot(k_tilde, cs_u*k_tilde, ls=':', c='k')

plt.plot(k_tilde, cs_d*k_tilde/(omega0*L0), ls='-', c='k', lw=1)
plt.plot(k_tilde, cs_u*k_tilde/(omega0*L0), ls='--', c='k', lw=1)
plt.plot(k_tilde[512:-1], np.sqrt(gz*k_tilde[512:-1]/(omega0*L0)), ls='-.', c='w')
q = 0.106
plt.plot(k_tilde[512:-1], np.sqrt(gz*k_tilde[512:-1]*((1-q)/(1+q))/(omega0*L0)), ls=(0, (3, 1, 1, 1)), c='w')
for i in range(0, 16):
    plt.plot(k_tilde, pmodes(k_tilde, i), c='w', ls=':')
    plt.plot(k_tilde, -pmodes(k_tilde, i), c='w', ls=':')

# plt.axvline(x=0, c='k', ls='--', lw=1)
# plt.axhline(y=0, c='k', ls='--', lw=1)
plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2*np.pi,2*np.pi)
#plt.ylim(0,10)
plt.colorbar()
plt.xlabel(r"$\tilde{k}_x$")
plt.ylabel(r"$\tilde{\omega}$")
# plt.savefig('plots/k_om2.png')
plt.show()

# %%
# np.savetxt('pdata/k_om.dat', np.fft.fftshift(logP))

# %%
indx_k = np.argmin(np.abs(k_tilde - 2))
k_tilde[indx_k]
# Out:
# 2.0

# %%
uz_fourier = np.fft.fftshift(uz_fourier)

# %%
P_k = np.abs(uz_fourier[:,indx_k])#/D**2)

# %%
# om_tilde[:]

# %%
fig = plt.figure(figsize=(16,4))
# for i in range(len(kz)):
#     plt.axvline(x = kz[i], color = 'b')

plt.plot(om_tilde[:], P_k[:], alpha=0.6)    # NOTE:Phere we have used the fftshift to 
plt.axvline(x=fmode(2), c='g', ls=':')                     #Shift the zero-frequency component to the center of the spectrum
plt.axvline(x=-fmode(2), c='g', ls=':')
for i in range(0,4):
    plt.axvline(x=pmodes(2,i), c='r', ls=':')
    plt.axvline(x=-pmodes(2,i), c='r', ls=':')
plt.ylim(0,)
plt.xlim(-6, 6)

plt.show()

# %%
pmodes(2,0)
# Out:
# 2.15

# %%
P = np.exp(logP)
P_k_prime = np.fft.fftshift(P)[:,indx_k]#/D**2)

# %%
fig = plt.figure(figsize=(16,4))
# for i in range(len(kz)):
#     plt.axvline(x = kz[i], color = 'b')

plt.plot(om_tilde[:], P_k_prime[:])    # NOTE:Phere we have used the fftshift to 
plt.ylim(0,)                                                                         #Shift the zero-frequency component to the center of the spectrum
plt.xlim(-6, 6)

plt.show()

# %%
uz_xz = yaver.y.uzmxz[indx_t1:indx_t2,:]
u_dim = uz_xz.shape

# %%
u_dim
# Out:
# (52923, 1024, 256)

# %%
# np.diff(uz_f_z[:,:,114]-uz_fourier)

# %%
uz_fourier = np.fft.fftn(uz_real[indx_t1:indx_t2,:,228], s=None, axes=(-2, -1), norm='ortho')

# %%
# indx_z = np.arange(0, 256, 2)
# indx_z = np.linspace(z[0], z[-1], u_dim[2])
indx_z = np.linspace(z[0], z[-1], 128)
# uz_f_z =  np.empty([np.shape(uz_xz[:,0,1])[0], np.shape(uz_xz[:,0,1])[1], len(indx_z)], dtype=complex)
uz_f_z =  np.empty([u_dim[0], u_dim[1], len(indx_z)], dtype=complex)


for i in range(len(indx_z)):
    # exec(f'uz_fourier_{i} = np.fft.fftn(uz_xz[indx_t1:indx_t2,:,indx_z[{i}]], s=None, axes=(-2, -1), norm=None)')
    # exec(f'uz_fourier_kin{i} = np.fft.fftn(uz_xz[:,0,{i}], s=None, axes=(-2, -1), norm=None)')
    uz_f_z[:,:,i] = np.fft.fftn(uz_xz[:,:,i], s=None, axes=(0, 1), norm='ortho')

# %%
# logP_z = np.fft.fftshift(np.log(np.abs(uz_f_z/D**2)), axes=(-2,-1))
logP_z = np.fft.fftshift(np.log(np.abs(uz_f_z/D**2)), axes=(0))
logP_z = np.fft.fftshift(logP_z, axes=(1))
# Out:
# /tmp/ipykernel_4053006/947804533.py:2: RuntimeWarning:
#
# divide by zero encountered in log

# %%
np.argmin(np.abs(indx_z-0))
# Out:
# 114

# %%
[X, Y] = np.meshgrid(k_tilde, om_tilde)
# plt.imshow(logP_z[:,:,114])
plt.pcolor(X, Y, logP_z[:,:,115])
# plt.imshow(np.fft.fftshift(logP))
plt.xlim(-10,10)
# plt.ylim(0,100)
plt.colorbar()

# %%
# [X, Y] = np.meshgrid(k_tilde, om_tilde)
# #plt.contourf(X, Y, logP, 1500, cmap='inferno', vmin=np.min(logP), vmax=np.max(logP))

# plt.contourf(X, Y, logP_z[:,:,80], 4000, cmap='afmhot_r', vmin=-4, vmax=np.max(logP))
# # plt.contourf(logP_z[200:,:,114], 4000, cmap='afmhot_r')
# # plt.contourf(logP_z[:,:,124], 4000, cmap='afmhot_r', vmin=-4, vmax=np.max(logP))
# # plt.plot(aa, np.sqrt(grz*aa), ls='dashdot', c='k')

# # plt.plot(k_tilde, cs_d*k_tilde/(omega0*L0), ls='-', c='k')
# # plt.plot(k_tilde, cs_u*k_tilde/(omega0*L0), ls='--', c='k')
# # plt.plot(k_tilde, np.sqrt(gz*k_tilde/(omega0*L0)), ls='-.', c='w')
# # plt.plot(k_tilde, np.sqrt(gz*k_tilde*((1-q)/(1+q))/(omega0*L0)), ls=(0, (3, 1, 1, 1)), c='w')
# # for i in range(0, 16):
# #     plt.plot(k_tilde, pmodes(k_tilde, i), c='w', ls=':')

# # plt.axvline(x=2, c='k')
# # plt.xlim(0,16)
# # plt.ylim(0,np.max(logP_z))
# # plt.ylim(0,np.max(om_til))
# # plt.xlim(0,10)
# # plt.ylim(0,np.max(om_tilde))
# plt.xlim(-2*np.pi,2*np.pi)
# plt.colorbar()
# plt.xlabel(r"$\tilde{k}_x$")
# plt.ylabel(r"$\tilde{\omega}$")
# plt.tight_layout()
# plt.savefig('plots/k_om_80.png')
# plt.show()

# %%
P_z = np.exp(logP_z)
P_z_k114 = P_z[:,np.argmin(np.abs(k_tilde-4)),114]

# %%
fig = plt.figure(figsize=(16,4))
# for i in range(len(kz)):
#     plt.axvline(x = kz[i], color = 'b')

plt.plot(om_tilde[:], P_z_k114)    # NOTE:Phere we have used the fftshift to 
plt.ylim(0,)                                                                         #Shift the zero-frequency component to the center of the spectrum
plt.xlim(-6, 6)

plt.show()

# %%
np.diff(t_gd)
# Out:
# array([0.04902267, 0.05097198, 0.05020714, ..., 0.05029297, 0.05065918,
#        0.04986572], dtype=float32)
